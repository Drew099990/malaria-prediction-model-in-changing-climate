# %%
import pandas as pd
import numpy as np

# Define the file path
file_path = 'C:\\Users\\DELL\\Desktop\\data.xlsx'

# Create dummy data resembling monthly weather and malaria patient data



print(f"Dummy data saved to '{file_path}'.")

# Now, attempt to load the data from the created file
try:
    df = pd.read_csv(file_path, parse_dates=['Date'], dayfirst=True)
    print("DataFrame loaded successfully.")
    print("\nDataFrame Info:")
    df.info()
    print("\nFirst 5 rows of the DataFrame:")
    print(df.head())
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found even after creation. Please check permissions.")
except KeyError:
    print("Error: 'Date' column not found or not in expected format. Please check the column name and data format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Dummy data saved to 'C:\Users\DELL\Desktop\data.xlsx'.
# An unexpected error occurred: 'utf-8' codec can't decode byte 0x82 in position 16: invalid start byte
